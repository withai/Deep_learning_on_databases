# %% [markdown]
# Deep Learning
# =============
#
# Assignment 5
# ------------
#
# The goal of this assignment is to train a Word2Vec skip-gram model over [Text8](http://mattmahoney.net/dc/textdata) data.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
# %matplotlib inline
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE
from tensorflow.contrib.tensorboard.plugins import projector

# %% [markdown]
# Download the data from the source website if necessary.

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified %s' % filename)
  else:
    print(statinfo.st_size)
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %% [markdown]
# Read the data into a string.

# %%
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words"""
  with zipfile.ZipFile(filename) as f:
    #print(f.read(f.namelist()[0]))
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data
  
words = read_data(filename)
print(words[0])
print('Data size %d' % len(words))
# Out:
# anarchism
# Data size 17005207

# %% [markdown]
# Build the dictionary and replace rare words with UNK token.

# %%
vocabulary_size = 50000

def build_dataset(words):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count = unk_count + 1
    data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
  return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5238, 3083, 12, 6, 195, 2, 3134, 46, 59, 156]

# %% [markdown]
# Function to generate a training batch for the skip-gram model.

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels



print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['as', 'anarchism', 'a', 'originated', 'as', 'term', 'a', 'of']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['anarchism', 'originated', 'term', 'a', 'as', 'of', 'originated', 'term']

# %% [markdown]
# Train a skip-gram model.

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(weights = softmax_weights, biases = softmax_biases, inputs = embed, 
                               labels = train_labels, num_sampled = num_sampled, num_classes = vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 8.037195
# Nearest to his: hash, factorials, precedent, savage, licensee, clever, remini, duel,
# Nearest to if: lethbridge, lucas, unitas, madeira, sentimental, inquire, communicate, dalmatian,
# Nearest to people: logik, dangerous, analyses, henze, zonker, kampen, boot, layered,
# Nearest to they: advertisers, brazen, commensurate, linguistics, inaccurately, speed, talbot, loot,
# Nearest to has: vigilantes, macdonald, bolger, unacceptable, persistent, pathologist, softening, dwellings,
# Nearest to new: sundance, vinge, centaurs, prone, kal, landfills, destry, steppes,
# Nearest to of: questioning, matrimony, broadsheet, rms, endemic, corfu, bains, theobromine,
# Nearest to not: rapids, microbes, evidences, behaviorism, rask, foothold, engrailed, suspensions,
# Nearest to states: entire, katy, printed, cezanne, suck, grip, nostalgia, najibullah,
# Nearest to up: manifest, ghats, ia, kg, salad, higgs, mccall, donovan,
# Nearest to which: steamship, lease, foreskin, clerihew, republica, cartels, traced, bedding,
# Nearest to from: simplistic, masers, each, smoking, bhangra, mtp, alexandrine, deposited,
# Nearest to will: conversation, eum, ecm, tenochtitl, quintessentially, warlord, iamblichus, equip,
# Nearest to united: focused, study, mep, shehri, diverted, boyne, henchman, laurentian,
# Nearest to by: curtailing, suspicious, mathrm, turbulence, monophysitism, alkanes, synonyms, zf,
# Nearest to called: pastry, uh, addictive, megafauna, mboxx, mawson, forgotten, evidences,
# Average loss at step 2000: 4.371875
# Average loss at step 4000: 3.863580
# Average loss at step 6000: 3.799827
# Average loss at step 8000: 3.686555
# Average loss at step 10000: 3.617875
# Nearest to his: their, the, its, s, constant, her, this, shea,
# Nearest to if: powerful, lucas, dalmatian, lethbridge, conspicuous, rumours, unitas, polluting,
# Nearest to people: dolby, flattery, hikers, petrel, sandbox, dangerous, logik, fief,
# Nearest to they: he, not, talbot, there, it, who, semifinals, advertisers,
# Nearest to has: had, was, is, have, bijelo, motorized, macdonald, totally,
# Nearest to new: kinks, vinge, prone, sundance, hogshead, contemporary, destry, centaurs,
# Nearest to of: in, foiled, for, theobromine, braces, at, vibrio, and,
# Nearest to not: they, it, bedding, granules, to, also, now, often,
# Nearest to states: entire, printed, wasted, heliocentric, brainwashing, roles, regulates, murphy,
# Nearest to up: fia, him, higgs, ghats, certifications, manifest, mole, grateful,
# Nearest to which: that, this, it, also, what, subgenre, occasionally, decried,
# Nearest to from: by, in, masers, into, smoking, with, at, template,
# Nearest to will: would, footwear, tursiops, snub, werewolf, crispin, laszlo, studded,
# Nearest to united: focused, study, boyne, henchman, colourless, junius, runtime, afghani,
# Nearest to by: from, during, pesos, was, as, aristide, against, through,
# Nearest to called: evidences, baldr, mansion, forgotten, boneyard, provisionally, mboxx, pastry,
# Average loss at step 12000: 3.607685
# Average loss at step 14000: 3.572515
# Average loss at step 16000: 3.409273
# Average loss at step 18000: 3.463826
# Average loss at step 20000: 3.538480
# Nearest to his: their, her, its, vindhya, the, constant, dumped, strathclyde,
# Nearest to if: but, although, when, motherland, powerful, dalmatian, sharing, rumours,
# Nearest to people: dolby, members, pca, dangerous, flattery, husk, hikers, children,
# Nearest to they: he, there, we, who, it, you, talbot, she,
# Nearest to has: had, was, have, is, bijelo, motorized, totally, glowing,
# Nearest to new: destry, prone, vinge, rackham, kinks, hogshead, block, sundance,
# Nearest to of: milder, for, troilus, ska, same, vibrio, labial, chymotrypsin,
# Nearest to not: it, still, now, also, to, they, generally, battering,
# Nearest to states: entire, wasted, hi, printed, murphy, heliocentric, stonework, brussels,
# Nearest to up: him, fia, manifest, vibrato, higgs, ghats, salad, certifications,
# Nearest to which: this, that, it, who, there, also, and, arcs,
# Nearest to from: into, in, after, through, between, at, over, within,
# Nearest to will: would, can, should, may, could, footwear, but, tursiops,
# Nearest to united: focused, henchman, boyne, study, colourless, sanger, invertible, afghani,
# Nearest to by: during, against, was, through, in, after, from, pesos,
# Nearest to called: boneyard, used, baldr, evidences, forgotten, mansion, proteins, welded,
# Average loss at step 22000: 3.501018
# Average loss at step 24000: 3.492576
# Average loss at step 26000: 3.481556
# Average loss at step 28000: 3.479447
# Average loss at step 30000: 3.503819
# Nearest to his: their, her, its, the, s, our, strathclyde, vindhya,
# Nearest to if: when, but, although, dalmatian, until, could, tincture, sharing,
# Nearest to people: members, pca, children, disciplinary, dolby, dangerous, those, jews,
# Nearest to they: there, we, he, it, you, who, she, not,
# Nearest to has: had, have, is, was, bijelo, motorized, already, having,
# Nearest to new: large, revitalized, rackham, syme, centaurs, gives, shetland, destry,
# Nearest to of: in, for, milder, from, including, heuristic, and, centrifugal,
# Nearest to not: still, they, now, to, generally, there, it, often,
# Nearest to states: entire, wasted, state, acl, secunda, rie, nations, drought,
# Nearest to up: him, fia, them, manifest, leading, ghats, intifada, vibrato,
# Nearest to which: this, that, what, who, it, also, alberta, but,
# Nearest to from: into, after, in, through, masers, within, of, under,
# Nearest to will: would, can, could, may, should, must, might, to,
# Nearest to united: focused, henchman, boyne, study, sanger, colourless, junius, invertible,
# Nearest to by: during, in, was, against, from, were, summit, aristide,
# Nearest to called: boneyard, used, electrician, unspeakable, baldr, henriette, arcs, loc,
# Average loss at step 32000: 3.505899
# Average loss at step 34000: 3.499611
# Average loss at step 36000: 3.453446
# Average loss at step 38000: 3.300962
# Average loss at step 40000: 3.429212
# Nearest to his: her, their, its, the, our, s, gch, strathclyde,
# Nearest to if: when, is, where, sharing, should, vcs, unitas, dalmatian,
# Nearest to people: members, pca, children, those, disciplinary, jews, dolby, anthemius,
# Nearest to they: we, there, he, you, it, she, who, not,
# Nearest to has: had, have, was, is, bijelo, motorized, glowing, having,
# Nearest to new: syme, destry, single, rackham, dismissing, wide, gateways, centaurs,
# Nearest to of: in, for, from, sennacherib, labial, fourth, centrifugal, enlil,
# Nearest to not: still, it, now, often, they, never, usually, battering,
# Nearest to states: nations, wasted, acl, state, secunda, kingdom, stonework, rie,
# Nearest to up: him, them, down, leading, fia, back, manifest, away,
# Nearest to which: that, this, also, who, what, it, often, these,
# Nearest to from: into, after, in, through, under, within, of, masers,
# Nearest to will: would, can, could, may, should, must, might, cannot,
# Nearest to united: henchman, study, junius, focused, boyne, sanger, abiathar, solvable,
# Nearest to by: as, when, after, methodism, during, with, southerners, be,
# Nearest to called: boneyard, used, considered, unspeakable, tz, baldr, mindaugas, cabin,
# Average loss at step 42000: 3.438575
# Average loss at step 44000: 3.454549
# Average loss at step 46000: 3.452747
# Average loss at step 48000: 3.352755
# Average loss at step 50000: 3.387839
# Nearest to his: their, her, its, my, the, our, suckling, precedent,
# Nearest to if: when, where, although, should, though, sharing, while, messalina,
# Nearest to people: members, children, pca, jews, dolby, things, those, them,
# Nearest to they: he, there, we, she, you, it, who, talbot,
# Nearest to has: had, have, is, was, cautioned, wedgwood, persson, glowing,
# Nearest to new: future, lexington, syme, shetland, scottish, correlations, ambrose, ottoman,
# Nearest to of: in, and, including, milder, blockading, troilus, labial, during,
# Nearest to not: now, still, generally, never, it, actually, often, usually,
# Nearest to states: nations, kingdom, wasted, state, secunda, stonework, acl, rie,
# Nearest to up: them, him, out, down, back, away, fia, off,
# Nearest to which: this, that, also, who, often, rap, sextus, what,
# Nearest to from: through, within, into, in, after, under, and, throughout,
# Nearest to will: would, can, could, may, should, must, might, does,
# Nearest to united: junius, henchman, boyne, sanger, abiathar, orbitals, groton, uprisings,
# Nearest to by: was, during, through, orientation, be, southerners, urals, in,
# Nearest to called: boneyard, used, loc, unspeakable, electrician, tz, oliva, cabin,
# Average loss at step 52000: 3.440509
# Average loss at step 54000: 3.427717
# Average loss at step 56000: 3.441478
# Average loss at step 58000: 3.400064
# Average loss at step 60000: 3.393784
# Nearest to his: her, their, its, my, our, gch, the, your,
# Nearest to if: when, where, while, sharing, though, should, although, then,
# Nearest to people: members, those, pca, things, children, scholars, scientists, jews,
# Nearest to they: we, there, he, you, she, these, it, resented,
# Nearest to has: had, have, is, was, provides, having, bijelo, seems,
# Nearest to new: syme, industrial, future, tarantino, ottoman, scientific, doses, hyginus,
# Nearest to of: in, for, barca, troilus, same, milder, deneb, ritualistic,
# Nearest to not: still, now, generally, usually, almost, never, it, examined,
# Nearest to states: nations, kingdom, state, wasted, acl, triumvirate, heap, secunda,
# Nearest to up: down, him, out, them, back, off, away, leading,
# Nearest to which: that, this, what, however, it, also, occasionally, rap,
# Nearest to from: through, into, within, masers, heldenplatz, under, untimely, after,
# Nearest to will: would, could, can, may, should, must, might, cannot,
# Nearest to united: orbitals, junius, henchman, boyne, abiathar, solvable, uprisings, colourless,
# Nearest to by: through, southerners, methodism, factual, when, sheikh, be, from,
# Nearest to called: used, boneyard, tz, unspeakable, considered, orbiting, oliva, defined,
# Average loss at step 62000: 3.239687
# Average loss at step 64000: 3.260014
# Average loss at step 66000: 3.400210
# Average loss at step 68000: 3.398857
# Average loss at step 70000: 3.353840
# Nearest to his: her, their, its, my, our, gch, your, strathclyde,
# Nearest to if: when, though, where, while, although, sharing, before, should,
# Nearest to people: members, women, children, pca, men, things, others, americans,
# Nearest to they: we, he, there, she, it, you, these, quickly,
# Nearest to has: had, have, is, was, bourbon, azar, contains, provides,
# Nearest to new: industrial, ottoman, scientific, kinks, syme, hogshead, worships, scottish,
# Nearest to of: including, troilus, original, for, milder, in, like, include,
# Nearest to not: still, generally, now, never, usually, actually, insufficiency, almost,
# Nearest to states: nations, kingdom, state, acl, wasted, secunda, countries, celtics,
# Nearest to up: them, down, off, back, out, him, away, rpp,
# Nearest to which: that, this, but, what, also, however, usually, these,
# Nearest to from: through, into, within, masers, by, between, heldenplatz, before,
# Nearest to will: would, may, could, can, must, should, might, cannot,
# Nearest to united: junius, groton, solvable, colourless, sanger, orbitals, henchman, boyne,
# Nearest to by: through, insults, gandhara, from, southerners, methodism, was, determinant,
# Nearest to called: boneyard, used, known, word, unspeakable, defined, tz, lent,
# Average loss at step 72000: 3.376521
# Average loss at step 74000: 3.346541
# Average loss at step 76000: 3.314417
# Average loss at step 78000: 3.349573
# Average loss at step 80000: 3.379920
# Nearest to his: her, their, its, my, our, your, gch, the,
# Nearest to if: when, before, though, should, although, then, where, while,
# Nearest to people: members, women, children, men, pca, those, scientists, anthemius,
# Nearest to they: we, he, there, she, you, it, these, who,
# Nearest to has: had, have, is, was, provides, azar, although, mutated,
# Nearest to new: koine, medieval, industrial, ottoman, worships, tarantino, syme, rackham,
# Nearest to of: barca, in, including, donating, ska, reuel, troilus, famicom,
# Nearest to not: still, actually, generally, usually, never, now, nor, insufficiency,
# Nearest to states: nations, state, kingdom, celtics, countries, us, gravely, secunda,
# Nearest to up: out, them, off, down, him, back, away, rpp,
# Nearest to which: that, this, what, usually, also, actually, sextus, where,
# Nearest to from: through, into, within, masers, after, by, during, unregistered,
# Nearest to will: would, could, can, may, must, should, might, cannot,
# Nearest to united: solvable, sanger, junius, boyne, colourless, orbitals, henchman, australopithecines,
# Nearest to by: when, hata, through, determinant, methodism, from, during, nintendo,
# Nearest to called: known, used, unspeakable, orbiting, boneyard, considered, monarchies, defined,
# Average loss at step 82000: 3.409602
# Average loss at step 84000: 3.411546
# Average loss at step 86000: 3.387924
# Average loss at step 88000: 3.357491
# Average loss at step 90000: 3.366769
# Nearest to his: her, their, its, my, our, your, the, gch,
# Nearest to if: when, where, before, though, is, then, while, perhaps,
# Nearest to people: women, children, members, men, those, wrap, pca, jews,
# Nearest to they: we, there, he, you, she, it, not, who,
# Nearest to has: had, have, is, was, having, provides, since, contains,
# Nearest to new: medieval, industrial, modern, scientific, ottoman, pai, rackham, mangeshkar,
# Nearest to of: including, for, barca, in, concerning, blockading, labial, entire,
# Nearest to not: still, actually, nor, generally, they, insufficiency, never, now,
# Nearest to states: nations, kingdom, state, us, countries, gravely, homeopathy, gernika,
# Nearest to up: out, down, off, them, back, him, away, rpp,
# Nearest to which: that, this, what, usually, also, sextus, both, based,
# Nearest to from: through, into, during, heldenplatz, masers, while, under, after,
# Nearest to will: would, could, can, may, must, should, might, cannot,
# Nearest to united: sanger, solvable, junius, presidential, boyne, uprisings, henchman, australopithecines,
# Nearest to by: when, through, during, while, with, against, hata, sheikh,
# Nearest to called: used, known, considered, orbiting, defined, unspeakable, monarchies, boneyard,
# Average loss at step 92000: 3.400496
# Average loss at step 94000: 3.252185
# Average loss at step 96000: 3.354329
# Average loss at step 98000: 3.242222
# Average loss at step 100000: 3.358011
# Nearest to his: her, their, my, our, its, your, the, strathclyde,
# Nearest to if: when, before, though, where, while, because, until, unless,
# Nearest to people: children, women, members, men, jews, wrap, individuals, scientists,
# Nearest to they: we, he, there, you, she, it, not, i,
# Nearest to has: had, have, is, was, since, provides, having, mutated,
# Nearest to new: modern, fictional, kri, medieval, industrial, specific, lexington, pai,
# Nearest to of: barca, and, reuel, concerning, in, ska, entire, labial,
# Nearest to not: actually, never, still, nor, generally, they, almost, now,
# Nearest to states: nations, kingdom, state, us, countries, gravely, celtics, heap,
# Nearest to up: out, off, them, down, him, back, away, rpp,
# Nearest to which: that, this, usually, what, actually, these, based, often,
# Nearest to from: into, through, masers, within, heldenplatz, during, aix, in,
# Nearest to will: would, can, could, may, must, should, might, cannot,
# Nearest to united: orbitals, boyne, presidential, sanger, solvable, colourless, headset, undo,
# Nearest to by: when, through, under, insults, during, been, comers, southerners,
# Nearest to called: used, known, named, considered, orbiting, referred, tilden, boneyard,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %% [markdown]
# ---
#
# Problem
# -------
#
# An alternative to skip-gram is another Word2Vec model called [CBOW](http://arxiv.org/abs/1301.3781) (Continuous Bag of Words). In the CBOW model, instead of predicting a context word from a word vector, you predict a word from the sum of all the word vectors in its context. Implement and evaluate a CBOW model trained on the text8 dataset.
#
# ---

# %%
data_index = 0

def generate_batch(batch_size, skip_window):
  global data_index
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  batch = np.ndarray(shape=(batch_size, span - 1), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size):
    buffer_list = list(buffer)
    labels[i, 0] = buffer_list.pop(skip_window)
    batch[i] = buffer_list
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels



print('data:', [reverse_dictionary[di] for di in data[:8]])

for skip_window in [1, 2]:
    data_index = 0
    batch, labels = generate_batch(batch_size=4, skip_window=skip_window)
    print('\nskip_window = %d:' % (skip_window))
    print('    batch:', [[reverse_dictionary[w] for w in bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(4)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# skip_window = 1:
#     batch: [['anarchism', 'as'], ['originated', 'a'], ['as', 'term'], ['a', 'of']]
#     labels: ['originated', 'as', 'a', 'term']
#
# skip_window = 2:
#     batch: [['anarchism', 'originated', 'a', 'term'], ['originated', 'as', 'term', 'of'], ['as', 'a', 'of', 'abuse'], ['a', 'term', 'abuse', 'first']]
#     labels: ['as', 'a', 'term', 'of']

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
#num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size, 2 * skip_window])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(weights = softmax_weights, biases = softmax_biases, inputs = tf.reduce_sum(embed, 1) 
                               ,labels = train_labels, num_sampled = num_sampled, num_classes = vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 7.740070
# Nearest to after: vibration, respondent, unter, logan, bridging, modena, pretend, renoir,
# Nearest to be: haihowak, inter, periodicals, superfluous, stanton, argentine, atlases, idleness,
# Nearest to american: bijection, languished, cycladic, madrigal, nanosystems, moravian, claudia, faction,
# Nearest to were: jscript, exploration, oxford, establish, zoroaster, corrode, lamport, catastrophic,
# Nearest to this: scheduler, shatt, rao, cathodes, overworld, denethor, mendelevium, radical,
# Nearest to at: quart, uppsala, overactive, siam, prematurely, bresson, saguinus, bumpy,
# Nearest to up: menander, combinations, stewart, calamity, zombie, cabling, hostel, lebedev,
# Nearest to of: likeness, satirizes, acf, unpaired, lal, foal, dearly, universally,
# Nearest to people: daddy, date, mountain, lapd, woo, kann, busan, artefact,
# Nearest to during: brilliantly, raves, vegetarianism, diego, quarried, abbey, pizarro, verde,
# Nearest to from: otis, messerschmitt, tomino, grange, presupposition, modelled, moment, nigh,
# Nearest to most: tuples, internment, afrikaners, robespierre, quatrain, connection, nadi, prejudicial,
# Nearest to some: dropped, showed, dukakis, blower, hyphenated, bartlett, corcovado, istria,
# Nearest to as: monarchical, vyasa, keynote, gain, hammerstein, chaucer, nsson, metals,
# Nearest to not: traverses, spiritualism, mummy, schottenheimer, intermarriages, alf, gypsum, subtitle,
# Nearest to had: harmonicas, strachey, langston, curvature, wicket, fade, cannibals, falsehoods,
# Average loss at step 2000: 4.086503
# Average loss at step 4000: 3.559162
# Average loss at step 6000: 3.392171
# Average loss at step 8000: 3.246021
# Average loss at step 10000: 3.172680
# Nearest to after: yoruba, vibration, during, uniformed, for, sundown, cleave, before,
# Nearest to be: have, was, been, were, robson, driscoll, refer, kpa,
# Nearest to american: frescoes, tunneling, surprised, english, shaikh, maggie, tortoise, ganymede,
# Nearest to were: are, was, had, have, rheims, letterbox, be, been,
# Nearest to this: it, which, the, his, their, any, he, offshoot,
# Nearest to at: in, during, from, bresson, gendarmerie, dualism, phraseology, taper,
# Nearest to up: menander, cabling, fairfax, gog, nvidia, harnessed, aiding, gorillas,
# Nearest to of: kyu, remembers, taxing, outcome, jaime, foal, ladas, edgerton,
# Nearest to people: date, thoroughfare, clays, those, persons, daddy, dismantling, upright,
# Nearest to during: at, melvyn, in, after, brilliantly, envisaged, airfoil, aedui,
# Nearest to from: in, through, into, nests, throughout, at, springboard, upon,
# Nearest to most: more, many, some, incarnation, nadi, voltaic, moko, venus,
# Nearest to some: many, these, several, amended, lows, any, all, those,
# Nearest to as: marmite, gracious, maoi, for, mediator, debrecen, disambiguate, when,
# Nearest to not: also, generally, never, mazarin, sometimes, cautious, motivated, probably,
# Nearest to had: has, have, was, were, received, ballpark, karelia, rinzai,
# Average loss at step 12000: 3.202376
# Average loss at step 14000: 3.151378
# Average loss at step 16000: 3.172931
# Average loss at step 18000: 3.126156
# Average loss at step 20000: 2.987470
# Nearest to after: before, yoruba, during, for, at, when, neanderthals, nnn,
# Nearest to be: been, have, being, refer, driscoll, is, produce, were,
# Nearest to american: english, ganymede, islamic, internal, austrian, maggie, jagged, african,
# Nearest to were: are, have, was, include, had, letterbox, be, headlined,
# Nearest to this: which, it, the, that, a, what, some, any,
# Nearest to at: during, in, on, towards, wheelchair, transnational, after, maratha,
# Nearest to up: them, out, slang, menander, back, him, cabling, desertification,
# Nearest to of: in, harun, edgerton, for, taxing, dearly, reassembled, longford,
# Nearest to people: persons, thoroughfare, those, virulent, critics, animals, date, jug,
# Nearest to during: at, in, until, after, aedui, towards, airfoil, coastal,
# Nearest to from: through, nests, into, shun, maupassant, thoroughfares, between, springboard,
# Nearest to most: more, many, some, voltaic, lakshadweep, yusuf, moko, cinematographers,
# Nearest to some: many, these, several, certain, any, those, most, clergy,
# Nearest to as: when, marmite, mediator, produces, feasible, gracious, ck, aleutian,
# Nearest to not: still, never, generally, also, almost, now, embracing, sometimes,
# Nearest to had: has, have, was, received, were, ballpark, lodovico, faced,
# Average loss at step 22000: 3.069344
# Average loss at step 24000: 3.034872
# Average loss at step 26000: 3.009324
# Average loss at step 28000: 3.025599
# Average loss at step 30000: 3.005443
# Nearest to after: before, during, when, yoruba, behind, at, emphasises, without,
# Nearest to be: been, being, have, become, refer, was, goebbels, fantasies,
# Nearest to american: maggie, british, english, ganymede, islamic, austrian, tunneling, african,
# Nearest to were: are, have, was, had, been, include, being, those,
# Nearest to this: which, it, the, what, that, some, marge, gottorp,
# Nearest to at: during, transnational, in, after, subjective, delete, maratha, towards,
# Nearest to up: out, off, down, them, back, him, slang, gladiatorial,
# Nearest to of: in, including, foal, reassembled, harun, kumamoto, like, dearly,
# Nearest to people: persons, women, critics, observers, virulent, lamarckian, individuals, glee,
# Nearest to during: after, in, at, until, before, where, since, aedui,
# Nearest to from: through, into, nests, in, springboard, between, brahmin, beak,
# Nearest to most: some, more, many, voltaic, nadi, incarnation, modification, moko,
# Nearest to some: many, several, these, any, most, various, certain, those,
# Nearest to as: mediator, aleutian, marmite, tramiel, produces, when, manifest, arianism,
# Nearest to not: now, never, still, almost, subtitle, always, generally, usually,
# Nearest to had: has, have, was, were, having, received, sect, cycladic,
# Average loss at step 32000: 2.829233
# Average loss at step 34000: 2.953490
# Average loss at step 36000: 2.949561
# Average loss at step 38000: 2.941775
# Average loss at step 40000: 2.931411
# Nearest to after: before, during, when, yoruba, without, if, from, through,
# Nearest to be: have, been, is, produce, being, become, was, belonging,
# Nearest to american: british, canadian, african, indian, australian, islamic, english, italian,
# Nearest to were: are, have, had, was, been, being, those, include,
# Nearest to this: which, it, what, scheduler, there, piedmont, tran, another,
# Nearest to at: during, in, near, mohs, transnational, faithfully, maratha, moxie,
# Nearest to up: off, out, down, them, back, menander, cabling, him,
# Nearest to of: edgerton, foal, forbade, including, although, kumamoto, bushman, psychomotor,
# Nearest to people: women, men, critics, individuals, those, lamarckian, children, virulent,
# Nearest to during: after, in, before, until, at, from, throughout, since,
# Nearest to from: through, into, during, nests, springboard, between, beak, after,
# Nearest to most: more, some, many, less, voltaic, particularly, newbies, incarnation,
# Nearest to some: many, several, various, most, these, certain, any, all,
# Nearest to as: mediator, marmite, troglodytes, lovecraftian, manifest, kuznetsova, tramiel, concocted,
# Nearest to not: almost, still, subtitle, never, now, always, katharina, also,
# Nearest to had: have, has, was, were, having, hexameter, wanted, deport,
# Average loss at step 42000: 2.953579
# Average loss at step 44000: 2.962316
# Average loss at step 46000: 2.907843
# Average loss at step 48000: 2.870568
# Average loss at step 50000: 2.849279
# Nearest to after: before, when, during, without, yoruba, despite, dreaming, behind,
# Nearest to be: have, been, become, refer, being, produce, is, reach,
# Nearest to american: canadian, british, ganymede, english, maggie, french, and, german,
# Nearest to were: are, had, have, was, been, while, those, burney,
# Nearest to this: it, which, what, that, the, minimization, some, marge,
# Nearest to at: during, in, near, from, transnational, on, around, within,
# Nearest to up: off, out, down, back, him, away, them, cabling,
# Nearest to of: in, edgerton, including, although, from, foal, during, jaime,
# Nearest to people: women, individuals, persons, men, children, observers, today, citizens,
# Nearest to during: in, until, after, when, from, at, before, throughout,
# Nearest to from: during, through, in, into, between, beak, across, nests,
# Nearest to most: more, many, voltaic, particularly, some, less, looser, newbies,
# Nearest to some: many, several, these, any, certain, various, most, all,
# Nearest to as: curving, mediator, whereof, ashoka, aleutian, marmite, stopper, frosts,
# Nearest to not: now, still, subtitle, never, almost, really, always, otherwise,
# Nearest to had: has, have, having, were, was, since, ever, wanted,
# Average loss at step 52000: 2.891666
# Average loss at step 54000: 2.867047
# Average loss at step 56000: 2.859716
# Average loss at step 58000: 2.751896
# Average loss at step 60000: 2.833128
# Nearest to after: before, during, when, without, despite, if, yoruba, behind,
# Nearest to be: been, have, become, reach, being, were, generate, are,
# Nearest to american: canadian, british, english, australian, italian, german, maggie, spanish,
# Nearest to were: are, was, had, have, be, those, been, include,
# Nearest to this: it, which, the, what, piedmont, every, some, gottorp,
# Nearest to at: in, during, on, near, under, hyi, maratha, within,
# Nearest to up: off, out, down, back, him, desertification, oc, away,
# Nearest to of: longford, including, although, edgerton, dining, following, reformatory, concerning,
# Nearest to people: women, men, children, individuals, persons, those, observers, citizens,
# Nearest to during: in, after, when, within, until, at, through, if,
# Nearest to from: through, into, during, across, nests, springboard, maupassant, shun,
# Nearest to most: more, many, some, voltaic, use, particularly, less, especially,
# Nearest to some: many, several, any, most, certain, these, each, various,
# Nearest to as: because, apollinaire, frosts, kuznetsova, ashoka, townhouse, buoyant, when,
# Nearest to not: never, actually, now, still, almost, subtitle, usually, really,
# Nearest to had: have, has, was, having, were, saw, previously, wanted,
# Average loss at step 62000: 2.835086
# Average loss at step 64000: 2.777462
# Average loss at step 66000: 2.762718
# Average loss at step 68000: 2.715969
# Average loss at step 70000: 2.784342
# Nearest to after: before, during, when, despite, yoruba, while, without, if,
# Nearest to be: been, have, become, being, refer, reach, contain, belonging,
# Nearest to american: canadian, british, italian, australian, english, german, instantiation, pictured,
# Nearest to were: are, was, have, had, include, those, been, clue,
# Nearest to this: which, it, the, some, what, any, another, each,
# Nearest to at: near, during, on, in, before, under, hyi, within,
# Nearest to up: off, out, down, back, together, desertification, away, oc,
# Nearest to of: in, including, jaime, schoolmaster, edgerton, daniels, tapering, kyu,
# Nearest to people: women, men, children, persons, americans, person, individuals, citizens,
# Nearest to during: after, in, within, until, since, throughout, under, at,
# Nearest to from: through, into, nests, springboard, during, between, across, via,
# Nearest to most: more, less, particularly, some, especially, many, voltaic, newbies,
# Nearest to some: many, several, certain, any, these, most, various, decapitate,
# Nearest to as: kuznetsova, prut, mongolian, when, ashoka, apollinaire, rsdlp, haunted,
# Nearest to not: now, never, subtitle, almost, really, always, actually, normally,
# Nearest to had: has, have, having, was, were, saw, ever, received,
# Average loss at step 72000: 2.797043
# Average loss at step 74000: 2.641847
# Average loss at step 76000: 2.801205
# Average loss at step 78000: 2.828149
# Average loss at step 80000: 2.777997
# Nearest to after: before, during, when, despite, yoruba, for, without, though,
# Nearest to be: become, been, reach, have, remain, get, produce, buy,
# Nearest to american: canadian, italian, australian, british, french, english, indian, german,
# Nearest to were: are, was, have, had, include, those, been, modularity,
# Nearest to this: which, it, what, another, that, gottorp, worldcom, every,
# Nearest to at: during, in, under, near, within, before, after, legislators,
# Nearest to up: off, down, back, out, away, together, him, desertification,
# Nearest to of: in, reassembled, including, kyu, include, and, during, forbade,
# Nearest to people: women, men, persons, children, those, americans, individuals, citizens,
# Nearest to during: after, in, when, throughout, within, at, before, through,
# Nearest to from: through, via, across, nests, springboard, ataxia, into, maupassant,
# Nearest to most: more, particularly, less, some, many, voltaic, especially, newbies,
# Nearest to some: many, several, certain, any, these, various, most, those,
# Nearest to as: kuznetsova, mediator, like, rsdlp, curving, when, ashoka, frosts,
# Nearest to not: never, still, subtitle, either, almost, actually, really, now,
# Nearest to had: has, have, having, was, were, hexameter, saw, ever,
# Average loss at step 82000: 2.664144
# Average loss at step 84000: 2.775537
# Average loss at step 86000: 2.739889
# Average loss at step 88000: 2.755867
# Average loss at step 90000: 2.736107
# Nearest to after: before, during, despite, when, without, following, within, thereafter,
# Nearest to be: become, been, refer, being, have, get, remain, reach,
# Nearest to american: canadian, british, australian, italian, french, african, indian, english,
# Nearest to were: are, have, had, was, been, include, those, being,
# Nearest to this: which, it, what, the, some, another, that, piedmont,
# Nearest to at: near, during, in, throughout, under, jacobitism, consonances, davao,
# Nearest to up: off, down, back, out, away, him, together, them,
# Nearest to of: kyu, longford, including, concerning, forbade, despite, gagauz, although,
# Nearest to people: women, men, children, persons, individuals, citizens, americans, jews,
# Nearest to during: in, after, before, throughout, within, until, since, following,
# Nearest to from: through, across, nests, into, via, during, springboard, beak,
# Nearest to most: more, some, many, less, particularly, especially, newbies, among,
# Nearest to some: many, several, any, most, these, certain, various, both,
# Nearest to as: mongolian, malthusian, curving, including, like, townhouse, marmite, tramiel,
# Nearest to not: never, actually, now, subtitle, almost, either, still, normally,
# Nearest to had: has, have, was, having, were, gained, since, saw,
# Average loss at step 92000: 2.678668
# Average loss at step 94000: 2.724064
# Average loss at step 96000: 2.705127
# Average loss at step 98000: 2.370303
# Average loss at step 100000: 2.397384
# Nearest to after: before, during, despite, when, without, following, for, if,
# Nearest to be: become, been, remain, have, being, produce, refer, get,
# Nearest to american: canadian, english, australian, british, italian, german, austrian, irish,
# Nearest to were: are, have, was, include, had, be, been, seem,
# Nearest to this: which, it, another, some, what, his, the, any,
# Nearest to at: during, in, near, transnational, after, on, throughout, within,
# Nearest to up: off, out, down, back, together, away, him, forward,
# Nearest to of: daniels, in, tapering, despite, kyu, donelson, balanchine, patriarchates,
# Nearest to people: women, men, children, persons, individuals, citizens, man, person,
# Nearest to during: in, after, at, despite, before, until, when, throughout,
# Nearest to from: through, across, brahmin, via, springboard, shun, pluto, beak,
# Nearest to most: more, less, especially, particularly, voltaic, some, many, newbies,
# Nearest to some: many, several, any, certain, various, numerous, these, this,
# Nearest to as: apollinaire, whereof, ashoka, tramiel, after, shankar, frosts, marmite,
# Nearest to not: never, really, actually, subtitle, now, t, always, rarely,
# Nearest to had: has, have, having, was, were, saw, never, doesn,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %% [markdown]
# ---
# Visualizing the embeddings using Tensorboard - Embedding Projector
# ---

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
#num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size, 2 * skip_window])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(weights = softmax_weights, biases = softmax_biases, inputs = tf.reduce_sum(embed, 1) 
                               ,labels = train_labels, num_sampled = num_sampled, num_classes = vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))
  
    
  tf.summary.scalar("loss", loss)
  tf.summary.histogram("histogram loss", loss)
  # because you have several summaries, we should merge them all
  # into one op to make it easier to manage
  summary_op = tf.summary.merge_all()
  
  saver = tf.train.Saver()
# Out:
# INFO:tensorflow:Summary name histogram loss is illegal; using histogram_loss instead.

# %%
LOG_DIR = '/home/yashwanth/home/udacity-DL/assignment-5'   #your local directory
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()

  ckpt = tf.train.get_checkpoint_state(os.path.dirname(LOG_DIR))
  # if that checkpoint exists, restore from checkpoint
  if ckpt and ckpt.model_checkpoint_path:
    saver.restore(session, ckpt.model_checkpoint_path)
    
  print('Initialized')
  average_loss = 0
  writer = tf.summary.FileWriter('improved_graph/lr', session.graph)

  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l, summary = session.run([optimizer, loss, summary_op], feed_dict=feed_dict)
    average_loss += l
    writer.add_summary(summary, global_step=step)
    
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
  
  #preparing tensorboard - embedding projector
  embedding_var = tf.Variable(final_embeddings[1:num_points+1, :],  name='Embedding_of_word2Vec')
  session.run(embedding_var.initializer)

  config = projector.ProjectorConfig()
  summary_writer = tf.summary.FileWriter(LOG_DIR)

  embedding = config.embeddings.add()
  embedding.tensor_name = embedding_var.name

  # Comment out if you don't have metadata
  embedding.metadata_path = os.path.join(LOG_DIR, 'metadata.tsv')

  # Comment out if you don't want sprites
  #embedding.sprite.image_path = os.path.join(LOG_DIR, 'sprite.png')
  #embedding.sprite.single_image_dim.extend([imgs.shape[1], imgs.shape[1]])

  projector.visualize_embeddings(summary_writer, config)
  saver = tf.train.Saver([embedding_var])
  saver.save(session, os.path.join(LOG_DIR, 'model1.ckpt'), 1)
# Out:
# Initialized
# Average loss at step 0: 8.073489
# Nearest to three: beats, swivel, tilting, benz, ding, circularly, tla, kubrick,
# Nearest to on: szczecin, dreaded, browne, abstractly, perverse, alum, depth, saipan,
# Nearest to all: confidence, reorganised, kiosks, jeju, homologous, compute, cohn, theoretician,
# Nearest to the: courthouse, moncton, quays, elvis, inflection, waived, alc, clipped,
# Nearest to a: vie, foxx, exiles, anita, peyote, coen, advancing, shortened,
# Nearest to there: attendant, tanto, psyche, permafrost, aluma, shown, carnegie, karabakh,
# Nearest to if: avenged, homeomorphisms, pas, conlang, grandstand, kosovo, whenever, conflation,
# Nearest to war: ratsiraka, starr, mh, reims, wolfe, unwritten, paved, rectify,
# Nearest to are: burn, archival, whispers, maher, paulo, bettors, golf, refrigerator,
# Nearest to used: articulated, jolly, twinning, fido, remarque, waring, blasted, overriding,
# Nearest to five: rigour, filled, holds, umlaut, eurofighter, rapcore, downturn, notoriety,
# Nearest to history: cellini, franciscans, elvira, violations, standings, infertility, steiner, juices,
# Nearest to his: tranquility, reparations, disjunctive, coates, edi, oily, beta, grid,
# Nearest to years: quaternion, pp, falsifiable, mort, driest, theodora, whereby, radbruch,
# Nearest to over: elamites, pas, undulating, employment, lexicographic, mode, definable, courier,
# Nearest to most: quirky, sys, reviewer, withdrawals, cassel, hua, kalmar, movimiento,
# Average loss at step 2000: 4.069205
# Average loss at step 4000: 3.540164
# Average loss at step 6000: 3.481719
# Average loss at step 8000: 3.375433
# Average loss at step 10000: 3.096129
# Nearest to three: five, four, six, seven, eight, two, nine, zero,
# Nearest to on: upon, in, megas, aruba, saipan, wrap, propellants, from,
# Nearest to all: underlies, platforms, some, those, selberg, universalist, nazarbayev, dur,
# Nearest to the: this, their, his, its, a, cucumber, konkan, soundboard,
# Nearest to a: the, foxx, disagrees, settles, menander, spitfire, circumstances, mais,
# Nearest to there: it, they, tanto, now, he, which, shown, battlefront,
# Nearest to if: diamagnets, chlorus, when, vigilant, slipped, connick, rommel, before,
# Nearest to war: wolfe, plotted, strewn, horrendous, reims, ales, unwritten, hoyt,
# Nearest to are: were, have, is, detailing, was, basal, glacial, diamagnets,
# Nearest to used: referred, called, twinning, known, coprocessor, soundboard, azerbaijani, seen,
# Nearest to five: eight, four, six, three, zero, nine, seven, two,
# Nearest to history: number, list, spiral, granger, franciscans, gurps, numbers, robe,
# Nearest to his: their, its, her, the, offical, caria, christ, regimental,
# Nearest to years: bouncer, host, halfdan, driest, jericho, lonnie, spine, pp,
# Nearest to over: pas, undulating, emulate, mchenry, nk, recede, until, elamites,
# Nearest to most: more, some, unify, ecozone, iiis, palau, amalgamation, kangaroo,
# Average loss at step 12000: 3.238334
# Average loss at step 14000: 3.214280
# Average loss at step 16000: 3.127932
# Average loss at step 18000: 3.117674
# Average loss at step 20000: 3.150908
# Nearest to three: four, two, five, six, seven, eight, nine, one,
# Nearest to on: upon, through, during, in, uri, browne, hint, at,
# Nearest to all: some, various, those, both, any, every, sangha, many,
# Nearest to the: its, their, a, any, this, konkan, cucumber, bower,
# Nearest to a: the, any, glossaries, every, prerequisite, inherently, another, cristobal,
# Nearest to there: they, it, he, tanto, now, these, we, still,
# Nearest to if: when, before, chlorus, bomarc, schafer, although, vigilant, can,
# Nearest to war: plotted, wolfe, reims, horrendous, zorro, strewn, jdf, edd,
# Nearest to are: were, is, have, sideline, including, detailing, voight, mortimer,
# Nearest to used: known, seen, referred, soundboard, found, available, called, described,
# Nearest to five: four, seven, six, eight, zero, nine, three, two,
# Nearest to history: list, nsted, spiral, granger, number, judaism, exclusion, sdk,
# Nearest to his: her, their, its, s, your, my, coates, the,
# Nearest to years: days, months, decades, jericho, weeks, host, grind, halfdan,
# Nearest to over: off, emulate, phenomenal, diamondbacks, delle, recede, muonium, out,
# Nearest to most: more, some, many, less, seidel, luzon, all, inhabitants,
# Average loss at step 22000: 3.104036
# Average loss at step 24000: 3.066805
# Average loss at step 26000: 3.009185
# Average loss at step 28000: 2.991244
# Average loss at step 30000: 3.010547
# Nearest to three: five, eight, four, six, seven, two, nine, zero,
# Nearest to on: upon, through, in, around, within, megas, decins, interestingly,
# Nearest to all: those, many, some, these, both, various, several, every,
# Nearest to the: its, their, a, any, his, this, your, mobilized,
# Nearest to a: the, another, enough, any, menander, glossaries, electoral, every,
# Nearest to there: they, he, it, now, believed, we, still, often,
# Nearest to if: when, though, where, medusa, because, before, so, connick,
# Nearest to war: plotted, patan, jdf, zorro, reims, wolfe, remnants, unity,
# Nearest to are: were, is, have, voight, while, rupp, including, be,
# Nearest to used: known, referred, seen, found, available, intended, described, considered,
# Nearest to five: four, six, eight, seven, three, nine, two, zero,
# Nearest to history: list, spiral, nsted, mehmed, branch, sdk, exclusion, judaism,
# Nearest to his: her, their, your, its, my, the, our, caria,
# Nearest to years: days, months, decades, weeks, year, centuries, times, grind,
# Nearest to over: off, recede, phenomenal, emulate, out, around, concludes, copts,
# Nearest to most: more, many, less, some, inhabitants, seidel, luzon, amalgamation,
# Average loss at step 32000: 3.007288
# Average loss at step 34000: 2.886520
# Average loss at step 36000: 2.939965
# Average loss at step 38000: 2.940910
# Average loss at step 40000: 2.936236
# Nearest to three: four, six, five, eight, seven, two, nine, zero,
# Nearest to on: upon, during, through, within, under, in, constitutes, around,
# Nearest to all: many, some, both, those, every, any, various, several,
# Nearest to the: its, their, his, standardizing, kirkwood, any, takla, memorized,
# Nearest to a: another, stationed, enough, menander, rook, extraterrestrial, fripp, every,
# Nearest to there: they, it, he, she, believed, still, often, currently,
# Nearest to if: when, though, where, although, before, ulrike, since, however,
# Nearest to war: jdf, ales, plotted, patan, attic, remnants, reims, steering,
# Nearest to are: were, is, have, including, include, subterfuge, be, interbreeding,
# Nearest to used: known, seen, referred, considered, intended, described, found, available,
# Nearest to five: four, seven, six, eight, three, zero, nine, two,
# Nearest to history: list, religion, nsted, sdk, icann, university, antarctic, poland,
# Nearest to his: her, their, its, your, my, our, the, engels,
# Nearest to years: days, months, decades, weeks, centuries, times, year, hours,
# Nearest to over: off, around, recede, emulate, concludes, along, delle, nearly,
# Nearest to most: more, many, some, less, use, inhabitants, luzon, ascended,
# Average loss at step 42000: 2.827717
# Average loss at step 44000: 2.822737
# Average loss at step 46000: 2.875875
# Average loss at step 48000: 2.850760
# Average loss at step 50000: 2.864397
# Nearest to three: five, four, two, eight, six, seven, nine, zero,
# Nearest to on: upon, during, in, within, megas, around, towards, through,
# Nearest to all: both, many, some, every, various, certain, agust, those,
# Nearest to the: their, its, his, schelling, cucumber, ludovico, a, dealing,
# Nearest to a: another, the, menander, enough, nobody, fripp, foxx, arrears,
# Nearest to there: they, it, he, we, she, still, believed, minimally,
# Nearest to if: when, though, where, although, paine, before, since, doesn,
# Nearest to war: wars, jdf, plotted, patan, reims, remnants, commemorations, palate,
# Nearest to are: were, include, is, have, interbreeding, although, couturat, while,
# Nearest to used: described, referred, known, seen, considered, found, employed, available,
# Nearest to five: seven, eight, six, four, three, nine, two, zero,
# Nearest to history: list, sdk, status, map, evolution, nsted, latour, poland,
# Nearest to his: her, their, its, my, your, our, the, engels,
# Nearest to years: days, decades, months, weeks, hours, year, times, centuries,
# Nearest to over: off, around, emulate, through, across, trackless, recede, along,
# Nearest to most: less, some, more, many, particularly, ours, luzon, plow,
# Average loss at step 52000: 2.756782
# Average loss at step 54000: 2.869922
# Average loss at step 56000: 2.899400
# Average loss at step 58000: 2.825816
# Average loss at step 60000: 2.766779
# Nearest to three: four, five, six, seven, two, eight, nine, zero,
# Nearest to on: upon, around, within, pursuing, in, during, megas, decins,
# Nearest to all: both, various, many, some, several, certain, agust, most,
# Nearest to the: a, his, its, their, this, cheryl, standardizing, konkan,
# Nearest to a: the, another, glossaries, settles, every, arrears, menander, stationed,
# Nearest to there: they, it, he, she, we, tanto, usually, still,
# Nearest to if: when, though, where, since, doesn, macedonians, medusa, before,
# Nearest to war: wars, jdf, plotted, ales, algardi, steering, patan, commemorations,
# Nearest to are: were, include, have, is, uso, remain, voight, including,
# Nearest to used: described, known, seen, referred, employed, regarded, considered, found,
# Nearest to five: eight, four, seven, six, three, nine, zero, two,
# Nearest to history: list, map, poland, resources, sdk, status, forearms, story,
# Nearest to his: her, their, your, my, our, its, the, whose,
# Nearest to years: days, months, decades, weeks, hours, minutes, centuries, times,
# Nearest to over: around, off, emulate, across, colonists, along, through, recede,
# Nearest to most: more, less, many, some, all, use, particularly, inhabitants,
# Average loss at step 62000: 2.785559
# Average loss at step 64000: 2.835117
# Average loss at step 66000: 2.820226
# Average loss at step 68000: 2.739570
# Average loss at step 70000: 2.802298
# Nearest to three: four, two, five, seven, six, eight, nine, one,
# Nearest to on: upon, through, within, saipan, concerning, constitutes, in, around,
# Nearest to all: both, many, some, various, every, agust, those, certain,
# Nearest to the: their, its, his, this, our, dealing, any, bumped,
# Nearest to a: another, any, foxx, enough, the, every, cristobal, xu,
# Nearest to there: they, it, he, she, we, sometimes, usually, this,
# Nearest to if: when, though, where, medusa, before, callimico, int, then,
# Nearest to war: wars, plotted, jdf, highlander, ales, fandoms, inlay, patan,
# Nearest to are: were, include, have, is, contain, withers, subterfuge, containing,
# Nearest to used: known, required, designed, described, referred, intended, employed, found,
# Nearest to five: seven, four, eight, six, three, nine, zero, two,
# Nearest to history: list, map, academy, forearms, precarious, collection, modern, latour,
# Nearest to his: her, their, its, my, your, our, the, engels,
# Nearest to years: days, decades, months, weeks, hours, minutes, centuries, year,
# Nearest to over: around, across, off, galapagos, colonists, porta, concludes, nih,
# Nearest to most: more, some, many, less, especially, flank, both, luzon,
# Average loss at step 72000: 2.775141
# Average loss at step 74000: 2.752450
# Average loss at step 76000: 2.344916
# Average loss at step 78000: 2.481199
# Average loss at step 80000: 2.685091
# Nearest to three: four, five, six, seven, eight, two, nine, zero,
# Nearest to on: upon, within, in, concerning, around, constitutes, browne, improvising,
# Nearest to all: both, every, many, those, some, various, these, several,
# Nearest to the: his, a, their, her, its, this, our, cheryl,
# Nearest to a: another, the, marksmanship, therus, menander, settles, any, disagrees,
# Nearest to there: it, they, he, she, here, we, still, now,
# Nearest to if: when, though, before, where, however, callimico, without, did,
# Nearest to war: wars, jdf, plotted, battle, fandoms, constantine, highlander, perfume,
# Nearest to are: were, include, have, is, voight, those, contain, tend,
# Nearest to used: known, described, called, referred, designed, intended, seen, required,
# Nearest to five: four, six, seven, eight, three, nine, zero, two,
# Nearest to history: list, antiquities, contemporary, economy, lists, academy, medieval, pains,
# Nearest to his: her, their, my, your, its, our, the, whose,
# Nearest to years: decades, days, months, weeks, hours, minutes, year, centuries,
# Nearest to over: off, around, across, galapagos, along, concludes, nearly, emulate,
# Nearest to most: more, less, some, many, especially, particularly, luzon, ours,
# Average loss at step 82000: 2.684542
# Average loss at step 84000: 2.767503
# Average loss at step 86000: 2.772644
# Average loss at step 88000: 2.582511
# Average loss at step 90000: 2.753174
# Nearest to three: four, five, two, seven, six, eight, nine, zero,
# Nearest to on: upon, in, concerning, within, decins, around, browne, gabab,
# Nearest to all: both, some, various, many, those, every, certain, any,
# Nearest to the: their, its, this, his, our, a, some, bower,
# Nearest to a: another, any, the, no, therus, chunk, foxx, futurology,
# Nearest to there: they, it, we, she, still, he, now, usually,
# Nearest to if: when, though, before, where, then, since, without, sanitary,
# Nearest to war: wars, conflict, jdf, fandoms, ales, inlay, plotted, highlander,
# Nearest to are: were, is, have, include, exist, contain, remain, although,
# Nearest to used: intended, designed, known, referred, described, required, seen, employed,
# Nearest to five: four, seven, six, three, eight, nine, two, zero,
# Nearest to history: list, antiquities, academy, map, nsted, gotovina, loner, references,
# Nearest to his: her, their, my, your, its, our, the, caria,
# Nearest to years: days, decades, months, weeks, hours, minutes, year, centuries,
# Nearest to over: around, off, across, colonists, within, galapagos, nearly, ule,
# Nearest to most: more, less, some, many, especially, particularly, utrecht, luzon,
# Average loss at step 92000: 2.751331
# Average loss at step 94000: 2.759397
# Average loss at step 96000: 2.592692
# Average loss at step 98000: 2.534855
# Average loss at step 100000: 2.634264
# Nearest to three: four, two, six, eight, five, seven, nine, zero,
# Nearest to on: upon, within, around, in, through, concerning, mercantilists, constitutes,
# Nearest to all: both, various, those, agust, instead, several, many, every,
# Nearest to the: their, his, its, a, our, cheryl, agi, this,
# Nearest to a: another, the, every, dmc, any, no, menander, arrears,
# Nearest to there: they, it, she, he, we, today, required, generally,
# Nearest to if: when, though, before, where, since, then, sanitary, without,
# Nearest to war: wars, conflict, jdf, plotted, inlay, ales, cyber, fandoms,
# Nearest to are: were, have, include, contain, is, those, voight, be,
# Nearest to used: designed, intended, referred, required, described, employed, found, known,
# Nearest to five: six, seven, four, eight, nine, zero, three, two,
# Nearest to history: list, resources, map, references, trend, lists, development, antiquities,
# Nearest to his: her, their, your, my, its, our, the, whose,
# Nearest to years: decades, months, days, hours, weeks, year, minutes, centuries,
# Nearest to over: around, off, across, colonists, nearly, ule, galapagos, along,
# Nearest to most: more, less, some, many, particularly, especially, both, various,

# %%
num_points = 400

#addition of metadata, names of the word vectors
words = [reverse_dictionary[i] for i in range(1, num_points+1)]
metadata_file = open(os.path.join(LOG_DIR, 'metadata.tsv'), 'w')
metadata_file.write('Name\tClass\n')
for i in range(num_points):
    metadata_file.write('%06d\t%s\n' % (i, words[i]))
metadata_file.close()

# %% [markdown]
# To visualize the word vectors using Tensorboard - Embedding projector, run the following command in terminal
#
# tensorboard --logdir=LOG_DIR

# %% [markdown]
# ![](5_word2Vec_TSNE.png)

# %% [markdown]
# Observations from this 3d - vector space show " usually, often, sometimes " are similar
